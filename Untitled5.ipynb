# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # reading the dataset

# %%
iris = 'iris.xls'
df = pd.read_excel(iris)

# %% [markdown]
# # printing the dataset

# %%
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # displaying the columns

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # mean of each column

# %%
df.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # checking for null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %% [markdown]
# # visualizations

# %% [markdown]
# # 1 box plot

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='SL',y='SW',hue='Classification',data=df)
plt.title('Sepal length vs Sepal width',size=20)
plt.figure(figsize=(20,10))
sns.boxplot(x='PL',y='PW',hue='Classification',data=df)
plt.title('Petal length vs Petal width',size=20)
# Out:
# Text(0.5, 1.0, 'Petal length vs Petal width')

# %% [markdown]
# # 2 violin plot

# %%
plt.figure(figsize=(15,15))
sns.violinplot(x='Classification',y='PL',data=df)
plt.title('Petal length of different Classification')
# Out:
# Text(0.5, 1.0, 'Petal length of different Classification')

# %% [markdown]
# # 3 strip plot

# %%
plt.figure(figsize=(15,15))
sns.stripplot(x='Classification',y='SL',data=df)
plt.title('Sepal length of different Classification')
# Out:
# Text(0.5, 1.0, 'Sepal length of different Classification')

# %% [markdown]
# # 4 swarm plot

# %%
plt.figure(figsize=(15,15))
sns.swarmplot(x='Classification',y='SW',data=df,hue='Classification')
plt.title('Sepal width of different Classification')
# Out:
# Text(0.5, 1.0, 'Sepal width of different Classification')
